# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolerdz/Evaluacion/blob/main/Extraccion_AIRBNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 12.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post4-py3-none-any.whl size=2973 sha256=94eb7bbc2e1d44117356692a5e033dad88c1e6a2c1a2b94469fb3a5d44b9cfbe
#   Stored in directory: /root/.cache/pip/wheels/46/b8/69/4f7789b7d2fc0718a44cbc4ae5d40970a40c22c472ae50f0a1
# Successfully built sklearn
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ...

# %%
from funpymodeling.exploratory import freq_tbl

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
california= pd.read_csv('data_cleanCalifornia', index_col= 0) 
espana = pd.read_csv("data_cleanGirona.csv")
mexico = pd.read_csv("data_cleanMexico")
# Out:
# <ipython-input-14-672ee3839ec6>:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   espana = pd.read_csv("data_cleanGirona.csv")

# %%
california
# Out:
#                                           listing_url last_scraped  \
# 0                    https://www.airbnb.com/rooms/958   06/03/2023
# 1                   https://www.airbnb.com/rooms/5858   06/03/2023
# 2                   https://www.airbnb.com/rooms/8142   06/03/2023
# 3                   https://www.airbnb.com/rooms/8339   06/03/2023
# 4                   https://www.airbnb.com/rooms/8739   06/03/2023
# ...                                               ...          ...
# 6931  https://www.airbnb.com/rooms/818195233784141985   06/03/2023
# 6932  https://www.airbnb.com/rooms/818231243893035313   06/03/2023
# 6933  https://www.airbnb.com/rooms/818396267693629070   06/03/2023
# 6934  https://www.airbnb.com/rooms/818474518435984613   06/03/2023
# 6935  https://www.airbnb.com/rooms/818887060432463897   06/03/2023
#
#            source                                               name  \
# 0     city scrape              Bright, Modern Garden Unit - 1BR/1BTH
# ...

# %%
mexico
# Out:
#                  id                                      listing_url  \
# 0      2.056638e+06             https://www.airbnb.com/rooms/2056638
# 1      2.072354e+06             https://www.airbnb.com/rooms/2072354
# 2      6.960370e+05              https://www.airbnb.com/rooms/696037
# 3      3.579700e+04               https://www.airbnb.com/rooms/35797
# 4      4.461600e+04               https://www.airbnb.com/rooms/44616
# ...             ...                                              ...
# 24220  8.539236e+17  https://www.airbnb.com/rooms/853923589855678923
# 24221  8.539667e+17  https://www.airbnb.com/rooms/853966732274073000
# 24222  8.542251e+17  https://www.airbnb.com/rooms/854225071295768399
# 24223  8.542477e+17  https://www.airbnb.com/rooms/854247693069190865
# 24224  8.542603e+17  https://www.airbnb.com/rooms/854260329845513725
#
#       last_scraped       source  \
# 0       2023-03-30  city scrape
# 1       2023-03-30  city scrape
# 2       2023-03-29  city scrape
# ...

# %%
espana
# Out:
#                          id                                      listing_url  \
# 0                   14551.0               https://www.airbnb.com/rooms/14551
# 1                 1205757.0             https://www.airbnb.com/rooms/1205757
# 2                 1212820.0             https://www.airbnb.com/rooms/1212820
# 3                  751638.0              https://www.airbnb.com/rooms/751638
# 4                   41342.0               https://www.airbnb.com/rooms/41342
# ...                     ...                                              ...
# 19651  858387000000000000.0  https://www.airbnb.com/rooms/858386613168601750
# 19652  858396000000000000.0  https://www.airbnb.com/rooms/858396134121337855
# 19653  858411000000000000.0  https://www.airbnb.com/rooms/858410917126332945
# 19654  858418000000000000.0  https://www.airbnb.com/rooms/858418062773719271
# 19655  858424000000000000.0  https://www.airbnb.com/rooms/858424461046143986
#
# ...

# %%
freq_tbl(mexico)
# Out:
#                                            listing_url  frequency  percentage  \
# 0                 https://www.airbnb.com/rooms/2056638          1    0.000041
# 1      https://www.airbnb.com/rooms/596483241760485724          1    0.000041
# 2      https://www.airbnb.com/rooms/596599799558211519          1    0.000041
# 3      https://www.airbnb.com/rooms/593628802596452011          1    0.000041
# 4      https://www.airbnb.com/rooms/590086498282984451          1    0.000041
# ...                                                ...        ...         ...
# 24220            https://www.airbnb.com/rooms/39134356          1    0.000041
# 24221            https://www.airbnb.com/rooms/39368238          1    0.000041
# 24222            https://www.airbnb.com/rooms/39368226          1    0.000041
# 24223            https://www.airbnb.com/rooms/39127840          1    0.000041
# 24224  https://www.airbnb.com/rooms/854260329845513725          1    0.000041
#
#        cumulative_perc
# ...

# %% [markdown]
# ## **Extraccion Caracteristicas**

# %% [markdown]
# # host_response_time

# %% [markdown]
# ## Mexico

# %%
table1M= freq_tbl(mexico['host_response_time'])
index1M= table1M.set_index('host_response_time')
index1M
# Out:
#                     frequency  percentage  cumulative_perc
# host_response_time
# within an hour          16996    0.701589         0.701618
# No registro              3091    0.127595         0.829219
# within a few hours       1966    0.081156         0.910378
# within a day             1450    0.059856         0.970236
# a few days or more        720    0.029721         0.999959
# Entire rental unit          1    0.000041         1.000000

# %%
index1M["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## España

# %%
table1E= freq_tbl(espana['host_response_time'])
index1E= table1E.set_index('host_response_time')
index1E
# Out:
#                     frequency  percentage  cumulative_perc
# host_response_time
# within an hour          12261    0.623779         0.623811
# within a few hours       2699    0.137312         0.761129
# within a day             2188    0.111315         0.872450
# No registro              2088    0.106227         0.978682
# a few days or more        418    0.021266         0.999949
# Entire villa                1    0.000051         1.000000

# %%
index1E["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## California

# %%
table1C= freq_tbl(california['host_response_time'])
index1C= table1C.set_index('host_response_time')
index1C
# Out:
#                     frequency  percentage  cumulative_perc
# host_response_time
# within an hour           4221    0.608564         0.608564
# within a few hours       1111    0.160179         0.768743
# No registro              1019    0.146915         0.915657
# within a day              452    0.065167         0.980825
# a few days or more        133    0.019175         1.000000

# %%
index1C["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# # host_acceptance_rate

# %% [markdown]
# ## Mexico

# %%
table2M= freq_tbl(mexico['host_acceptance_rate'])
index2M= table2M.set_index('host_acceptance_rate')
index2M
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                      11616    0.479505         0.479524
# 99%                        2704    0.111620         0.591149
# No registro                2043    0.084334         0.675487
# 98%                        1031    0.042559         0.718048
# 97%                         711    0.029350         0.747399
# ...                         ...         ...              ...
# 1 bath                        1    0.000041         0.999835
# 9%                            1    0.000041         0.999876
# 13%                           1    0.000041         0.999917
# 18%                           1    0.000041         0.999959
# 30%                           1    0.000041         1.000000
#
# [92 rows x 3 columns]

# %%
filtro2M= index2M[index2M['frequency']>700]
filtro2M
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                      11616    0.479505         0.479524
# 99%                        2704    0.111620         0.591149
# No registro                2043    0.084334         0.675487
# 98%                        1031    0.042559         0.718048
# 97%                         711    0.029350         0.747399
# 0%                          701    0.028937         0.776338

# %%
filtro2M.plot(kind = 'bar', width=1, figsize=(10,4))
plt.xlabel('host_acceptance_rate')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## España

# %%
table2E= freq_tbl(espana['host_acceptance_rate'])
index2E= table2E.set_index('host_acceptance_rate')
index2E
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                       7477    0.380393         0.380412
# 99%                        2221    0.112993         0.493411
# No registro                1153    0.058659         0.552073
# 98%                        1049    0.053368         0.605444
# 96%                         753    0.038309         0.643755
# ...                         ...         ...              ...
# 4 baths                       1    0.000051         0.999796
# 8%                            1    0.000051         0.999847
# 7%                            1    0.000051         0.999898
# 21%                           1    0.000051         0.999949
# 23%                           1    0.000051         1.000000
#
# [93 rows x 3 columns]

# %%
filtro2E= index2E[index2E['frequency']>700]
filtro2E
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                       7477    0.380393         0.380412
# 99%                        2221    0.112993         0.493411
# No registro                1153    0.058659         0.552073
# 98%                        1049    0.053368         0.605444
# 96%                         753    0.038309         0.643755
# 97%                         735    0.037393         0.681150

# %%
filtro2E.plot(kind = 'bar', width=1, figsize=(10,4))
plt.xlabel('host_acceptance_rate')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## California

# %%
table2C= freq_tbl(california['host_acceptance_rate'])
index2C= table2C.set_index('host_acceptance_rate')
index2C
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                      11616    0.479505         0.479524
# 99%                        2704    0.111620         0.591149
# No registro                2043    0.084334         0.675487
# 98%                        1031    0.042559         0.718048
# 97%                         711    0.029350         0.747399
# ...                         ...         ...              ...
# 1 bath                        1    0.000041         0.999835
# 9%                            1    0.000041         0.999876
# 13%                           1    0.000041         0.999917
# 18%                           1    0.000041         0.999959
# 30%                           1    0.000041         1.000000
#
# [92 rows x 3 columns]

# %%
filtro2C= index2C[index2C['frequency']>700]
filtro2C
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                      11616    0.479505         0.479524
# 99%                        2704    0.111620         0.591149
# No registro                2043    0.084334         0.675487
# 98%                        1031    0.042559         0.718048
# 97%                         711    0.029350         0.747399
# 0%                          701    0.028937         0.776338

# %%
filtro2C.plot(kind = 'bar', width=1, figsize=(10,4))
plt.xlabel('host_acceptance_rate')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# # host_identity_verified

# %% [markdown]
# ## Mexico

# %%
table3M= freq_tbl(mexico['host_identity_verified'])
index3M= table3M.set_index('host_identity_verified')
index3M
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                           22300    0.920537         0.920575
# f                            1924    0.079422         1.000000

# %%
index3M.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ## España

# %%
table3E= freq_tbl(espana['host_identity_verified'])
index3E= table3E.set_index('host_identity_verified')
index3E
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                           17276    0.878917         0.878962
# f                            2261    0.115028         0.993996
# No registro                   117    0.005952         0.999949
# HUTG000237                      1    0.000051         1.000000

# %%
filtro3E= index3E[index3E['frequency']>100]
filtro3E
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                           17276    0.878917         0.878962
# f                            2261    0.115028         0.993996
# No registro                   117    0.005952         0.999949

# %%
filtro3E.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ## California

# %%
table3C= freq_tbl(california['host_identity_verified'])
index3C= table3C.set_index('host_identity_verified')
index3C
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                           22300    0.920537         0.920575
# f                            1924    0.079422         1.000000

# %%
index3C.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# # property_types

# %% [markdown]
# ## Mexico

# %%
table4M= freq_tbl(mexico['property_type'])
index4M= table4M.set_index('property_type')
index4M
# Out:
#                               frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                 8144    0.336182         0.336196
# Entire condo                       3363    0.138824         0.475025
# Private room in rental unit        2860    0.118060         0.593089
# Private room in home               2009    0.082931         0.676024
# Entire loft                        1584    0.065387         0.741413
# ...                                 ...         ...              ...
# Private room in barn                  1    0.000041         0.999835
# Private room in earthen home          1    0.000041         0.999876
# Shared room in tiny home              1    0.000041         0.999917
# Private room in tower                 1    0.000041         0.999959
# Shared room in tent                   1    0.000041         1.000000
#
# [93 rows x 3 columns]

# %%
filtro4M= index4M[index4M['frequency']>200]
filtro4M
# Out:
#                                     frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                       8144    0.336182         0.336196
# Entire condo                             3363    0.138824         0.475025
# Private room in rental unit              2860    0.118060         0.593089
# Private room in home                     2009    0.082931         0.676024
# Entire loft                              1584    0.065387         0.741413
# Entire serviced apartment                1067    0.044045         0.785461
# Private room in condo                     917    0.037853         0.823316
# Entire home                               661    0.027286         0.850603
# Room in hotel                             381    0.015728         0.866331
# Private room in guest suite               297    0.012260         0.878591
# Private room in serviced apartment        295    0.012178         0.890769
# ...

# %%
filtro4M["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## España

# %%
table4E= freq_tbl(espana['property_type'])
index4E= table4E.set_index('property_type')
index4E
# Out:
#                               frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                 9339    0.475122         0.475146
# Entire home                        3703    0.188390         0.663546
# Entire villa                       1714    0.087200         0.750750
# Entire condo                       1400    0.071225         0.821979
# Entire cottage                      549    0.027930         0.849911
# ...                                 ...         ...              ...
# Private room in earthen home          1    0.000051         0.999796
# Private room in hut                   1    0.000051         0.999847
# 34733512                              1    0.000051         0.999898
# Private room in cabin                 1    0.000051         0.999949
# Private room in treehouse             1    0.000051         1.000000
#
# [78 rows x 3 columns]

# %%
filtro4E= index4E[index4E['frequency']>200]
filtro4E
# Out:
#                     frequency  percentage  cumulative_perc
# property_type
# Entire rental unit       9339    0.475122         0.475146
# Entire home              3703    0.188390         0.663546
# Entire villa             1714    0.087200         0.750750
# Entire condo             1400    0.071225         0.821979
# Entire cottage            549    0.027930         0.849911
# Entire townhouse          453    0.023046         0.872959
# Entire loft               217    0.011040         0.883999

# %%
filtro4E["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## California

# %%
table4C= freq_tbl(california['property_type'])
index4C= table4C.set_index('property_type')
index4C
# Out:
#                                     frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                       1848    0.266436         0.266436
# Entire condo                              879    0.126730         0.393166
# Private room in home                      853    0.122982         0.516148
# Entire home                               839    0.120963         0.637111
# Entire guest suite                        495    0.071367         0.708478
# Private room in rental unit               471    0.067907         0.776384
# Room in boutique hotel                    352    0.050750         0.827134
# Room in hotel                             265    0.038206         0.865340
# Private room in condo                     192    0.027682         0.893022
# Entire serviced apartment                 145    0.020905         0.913927
# Room in aparthotel                         68    0.009804         0.923731
# ...

# %%
filtro4C= index4C[index4C['frequency']>400]
filtro4C
# Out:
#                              frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                1848    0.266436         0.266436
# Entire condo                       879    0.126730         0.393166
# Private room in home               853    0.122982         0.516148
# Entire home                        839    0.120963         0.637111
# Entire guest suite                 495    0.071367         0.708478
# Private room in rental unit        471    0.067907         0.776384

# %%
filtro4C["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# # host_is_superhost

# %% [markdown]
# ## Mexico

# %%
table5M= freq_tbl(mexico['host_is_superhost'])
index5M= table5M.set_index('host_is_superhost')
index5M
# Out:
#                                                     frequency  percentage  \
# host_is_superhost
# f                                                       15426    0.636780
# t                                                        8792    0.362931
# No registro                                                 5    0.000206
# ["Smoke alarm", "Free street parking", "Single ...          1    0.000041
#
#                                                     cumulative_perc
# host_is_superhost
# f                                                          0.636806
# t                                                          0.999752
# No registro                                                0.999959
# ["Smoke alarm", "Free street parking", "Single ...         1.000000

# %%
filtro5M= index5M[index5M['frequency']>1000]
filtro5M
# Out:
#                    frequency  percentage  cumulative_perc
# host_is_superhost
# f                      15426    0.636780         0.636806
# t                       8792    0.362931         0.999752

# %%
filtro5M.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='host_is_superhost'>

# %% [markdown]
# ## España

# %%
table5E= freq_tbl(espana['host_is_superhost'])
index5E= table5E.set_index('host_is_superhost')
index5E
# Out:
#                                                     frequency  percentage  \
# host_is_superhost
# f                                                       16583    0.843661
# t                                                        3056    0.155474
# No registro                                                15    0.000763
# ["Carbon monoxide alarm", "Free parking on prem...          1    0.000051
#
#                                                     cumulative_perc
# host_is_superhost
# f                                                          0.843704
# t                                                          0.999186
# No registro                                                0.999949
# ["Carbon monoxide alarm", "Free parking on prem...         1.000000

# %%
filtro5E= index5E[index5E['frequency']>1000]
filtro5E
# Out:
#                    frequency  percentage  cumulative_perc
# host_is_superhost
# f                      16583    0.843661         0.843704
# t                       3056    0.155474         0.999186

# %%
filtro5E.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='host_is_superhost'>

# %% [markdown]
# ## California

# %%
table5C= freq_tbl(california['host_is_superhost'])
index5C= table5C.set_index('host_is_superhost')
index5C
# Out:
#                    frequency  percentage  cumulative_perc
# host_is_superhost
# f                       4058    0.585063         0.585063
# t                       2869    0.413639         0.998702
# No registro                9    0.001298         1.000000

# %%
filtro5C= index5C[index5C['frequency']>1000]
filtro5C
# Out:
#                    frequency  percentage  cumulative_perc
# host_is_superhost
# f                       4058    0.585063         0.585063
# t                       2869    0.413639         0.998702

# %%
index5C.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='host_is_superhost'>
